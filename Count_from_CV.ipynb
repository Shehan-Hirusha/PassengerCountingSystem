# %%
import cv2
from ultralytics import YOLO
import pandas as pd
import time
from datetime import datetime
import numpy as np
import requests
import json
import os

# Configuration
ESP8266_IP = "192.168.42.42"  
SEND_DELAY = 0.1  
CSV_FILE = 'count_data_realtime.csv'

class ESPConnection:
    def __init__(self, ip_address):
        self.ip = ip_address
        self.last_sent_time = 0
        self.last_sent_count = None
        
    def send_count(self, count):
        current_time = time.time()
        
        if (count != self.last_sent_count and 
            current_time - self.last_sent_time >= SEND_DELAY):
            
            try:
                url = f'http://{self.ip}/update-cv-count'
                response = requests.post(url, 
                                      json={'count': count},
                                      headers={'Content-Type': 'application/json'},
                                      timeout=1)
                
                if response.status_code == 200:
                    self.last_sent_count = count
                    self.last_sent_time = current_time
                    print(f"Successfully sent count {count} to ESP8266")
                else:
                    print(f"Failed to send count. Status code: {response.status_code}")
                    
            except requests.exceptions.RequestException as e:
                print(f"Error sending count to ESP8266: {e}")

def create_count_display(df):
    """Create a visual display of the count data"""
    height = 400
    width = 300
    display = np.ones((height, width, 3), dtype=np.uint8) * 255
    
    cv2.putText(display, "Count by Minute", (10, 30), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 0), 2)

    cv2.putText(display, "Time", (10, 70), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0), 1)
    cv2.putText(display, "Count", (200, 70), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0), 1)

    cv2.line(display, (10, 80), (width-10, 80), (0, 0, 0), 1)
    
    last_entries = df.tail(10)
    for i, (_, row) in enumerate(last_entries.iterrows()):
        y_pos = 110 + i * 30
        time_str = row['Time'].strftime('%H:%M')
        cv2.putText(display, time_str, (10, y_pos), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0), 1)
        cv2.putText(display, str(row['Count']), (200, y_pos), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0), 1)
    
    return display

def append_to_csv(data, filename):
    """Append a single row of data to CSV file"""
    # If file doesn't exist, create it with headers
    if not os.path.exists(filename):
        data.to_csv(filename, index=False)
    else:
        # Append without headers
        data.to_csv(filename, mode='a', header=False, index=False)

def main():
    # Initialize ESP connection
    esp = ESPConnection(ESP8266_IP)
    
    # Initialize YOLO model
    model = YOLO("yolov9c.pt")
    
    # Initialize video capture and writer
    cap = cv2.VideoCapture(1)
    assert cap.isOpened(), "Error opening webcam"
    
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    video_writer = cv2.VideoWriter("res//output_video.mp4", 
                                 cv2.VideoWriter_fourcc(*"mp4v"), 
                                 30, 
                                 (frame_width, frame_height))
    
    # Initialize tracking variables
    count_line_y = frame_height // 2
    count = 0
    tracked_objects = {}
    
    # Initialize time and DataFrame for count tracking
    start_time = time.time()
    current_minute = -1
    
    # Load existing CSV data if available
    if os.path.exists(CSV_FILE):
        df = pd.read_csv(CSV_FILE)
        df['Time'] = pd.to_datetime(df['Time'])  # Convert Time column back to datetime
    else:
        df = pd.DataFrame(columns=['Time', 'Count'])
    
    while True:
        success, frame = cap.read()
        if not success:
            print("Failed to grab frame")
            break
            
        # Update count data every minute
        elapsed_time = time.time() - start_time
        new_minute = int(elapsed_time // 60)
        
        if new_minute > current_minute:
            new_row = pd.DataFrame({
                'Time': [datetime.now().replace(second=0, microsecond=0)],
                'Count': [count]
            })
            # Append new row to CSV
            append_to_csv(new_row, CSV_FILE)
            # Update DataFrame for display
            df = pd.concat([df, new_row], ignore_index=True)
            current_minute = new_minute
            
        # Run YOLO detection and tracking
        results = model.track(frame, persist=True, tracker='botsort.yaml', iou=0.2)
        
        if results[0].boxes.id is not None:
            boxes = results[0].boxes.xyxy.cpu().numpy().astype(int)
            track_ids = results[0].boxes.id.cpu().numpy().astype(int)
            class_ids = results[0].boxes.cls.cpu().numpy().astype(int)
            
            for box, track_id, class_id in zip(boxes, track_ids, class_ids):
                if class_id == 0:  # Person class
                    x1, y1, x2, y2 = box
                    center_y = (y1 + y2) // 2
                    
                    if track_id in tracked_objects:
                        prev_center_y = tracked_objects[track_id]
                        
                        # Update count and send to ESP8266
                        if prev_center_y < count_line_y and center_y >= count_line_y:
                            count += 1
                            esp.send_count(count)
                        elif prev_center_y > count_line_y and center_y <= count_line_y:
                            count = max(0, count - 1)
                            esp.send_count(count)
                    
                    tracked_objects[track_id] = center_y
                    
                    # Draw bounding box
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    cv2.putText(frame, f"ID: {track_id}", (x1, y1 - 10),
                              cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        
        # Draw counting line and display count
        cv2.line(frame, (0, count_line_y), (frame_width, count_line_y), 
                (255, 0, 0), 2)
        cv2.putText(frame, f"Count: {count}", (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
        cv2.putText(frame, f"Time: {int(elapsed_time)}s", (10, 70),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
        
        # Create and display count data window
        count_display = create_count_display(df)
        cv2.imshow('Count Data', count_display)
        
        # Display and record
        video_writer.write(frame)
        cv2.imshow('Processed Feed', frame)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    # Save final count before closing
    final_row = pd.DataFrame({
        'Time': [datetime.now().replace(second=0, microsecond=0)],
        'Count': [count]
    })
    append_to_csv(final_row, CSV_FILE)
    
    # Cleanup
    cap.release()
    video_writer.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# 0: 384x640 3 persons, 1 chair, 297.8ms
# Speed: 3.9ms preprocess, 297.8ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 274.5ms
# Speed: 1.4ms preprocess, 274.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 chair, 249.7ms
# Speed: 1.2ms preprocess, 249.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 chair, 217.2ms
# Speed: 1.2ms preprocess, 217.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# 2025-01-04 18:05:56.035 python[4833:103723] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-01-04 18:05:56.035 python[4833:103723] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 384x640 5 persons, 1 chair, 221.6ms
# Speed: 1.2ms preprocess, 221.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 chair, 215.8ms
# Speed: 1.2ms preprocess, 215.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bowl, 217.2ms
# Speed: 1.1ms preprocess, 217.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 221.2ms
# Speed: 1.9ms preprocess, 221.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 219.2ms
# Speed: 1.5ms preprocess, 219.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 218.0ms
# Speed: 1.3ms preprocess, 218.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 225.4ms
# Speed: 1.2ms preprocess, 225.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 239.9ms
# Speed: 1.7ms preprocess, 239.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 238.7ms
# Speed: 1.3ms preprocess, 238.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 214.0ms
# Speed: 1.8ms preprocess, 214.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 chair, 216.9ms
# Speed: 1.5ms preprocess, 216.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 chair, 223.4ms
# Speed: 1.1ms preprocess, 223.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 chair, 215.5ms
# Speed: 2.0ms preprocess, 215.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 chair, 217.9ms
# Speed: 1.6ms preprocess, 217.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 chair, 222.5ms
# Speed: 1.5ms preprocess, 222.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 chair, 223.0ms
# Speed: 1.5ms preprocess, 223.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 235.3ms
# Speed: 1.4ms preprocess, 235.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 220.9ms
# Speed: 1.1ms preprocess, 220.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 217.3ms
# Speed: 1.1ms preprocess, 217.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 215.0ms
# Speed: 1.2ms preprocess, 215.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 216.5ms
# Speed: 1.9ms preprocess, 216.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 chair, 221.7ms
# Speed: 1.1ms preprocess, 221.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 handbag, 1 chair, 225.8ms
# Speed: 1.3ms preprocess, 225.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 handbag, 220.2ms
# Speed: 1.1ms preprocess, 220.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Successfully sent count 0 to ESP8266
#
# 0: 384x640 3 persons, 1 chair, 273.3ms
# Speed: 1.9ms preprocess, 273.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair,
4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 225.7ms
# Speed: 1.5ms preprocess, 225.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 222.2ms
# Speed: 1.2ms preprocess, 222.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 224.1ms
# Speed: 1.4ms preprocess, 224.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 3 chairs, 222.9ms
# Speed: 1.2ms preprocess, 222.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 224.9ms
# Speed: 1.2ms preprocess, 224.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 231.7ms
# Speed: 1.5ms preprocess, 231.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 221.8ms
# Speed: 1.5ms preprocess, 221.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 225.7ms
# Speed: 1.1ms preprocess, 225.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 228.8ms
# Speed: 2.0ms preprocess, 228.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 227.3ms
# Speed: 1.1ms preprocess, 227.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 3 chairs, 225.5ms
# Speed: 1.1ms preprocess, 225.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 222.5ms
# Speed: 1.2ms preprocess, 222.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 235.3ms
# Speed: 1.4ms preprocess, 235.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 222.1ms
# Speed: 1.3ms preprocess, 222.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 226.5ms
# Speed: 1.5ms preprocess, 226.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 227.4ms
# Speed: 1.2ms preprocess, 227.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 254.1ms
# Speed: 1.1ms preprocess, 254.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 223.8ms
# Speed: 1.5ms preprocess, 223.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 1 laptop, 223.0ms
# Speed: 1.6ms preprocess, 223.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 1 laptop, 228.7ms
# Speed: 1.4ms preprocess, 228.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 1 laptop, 227.1ms
# Speed: 1.2ms preprocess, 227.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 1 laptop, 225.9ms
# Speed: 1.3ms preprocess, 225.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 1 laptop, 225.9ms
# Speed: 1.2ms preprocess, 225.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 1 laptop, 223.3ms
# Speed: 1.2ms preprocess, 223.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 3 chairs, 248.3ms
# Speed: 1.5ms preprocess, 248.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 1 laptop, 223.8ms
# Speed: 1.4ms preprocess, 223.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 221.4ms
# Speed: 1.2ms preprocess, 221.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 1 laptop, 236.5ms
# Speed: 1.7ms preprocess, 236.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 223.6ms
# Speed: 1.1ms preprocess, 223.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 1 laptop, 222.6ms
# Speed: 1.6ms preprocess, 222.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 1 laptop, 224.8ms
# Speed: 1.7ms preprocess, 224.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 224.0ms
# Speed: 1.4ms preprocess, 224.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 1 laptop, 224.6ms
# Speed: 1.4ms preprocess, 224.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 1 laptop, 225.3ms
# Speed: 1.2ms preprocess, 225.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 1 laptop, 250.2ms
# Speed: 1.5ms preprocess, 250.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 3 chairs, 232.3ms
# Speed: 1.8ms preprocess, 232.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 1 laptop, 229.2ms
# Speed: 1.2ms preprocess, 229.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 3 chairs, 232.7ms
# Speed: 1.2ms preprocess, 232.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 232.5ms
# Speed: 1.1ms preprocess, 232.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 3 chairs, 223.3ms
# Speed: 1.1ms preprocess, 223.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 226.1ms
# Speed: 1.5ms preprocess, 226.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 227.2ms
# Speed: 1.6ms preprocess, 227.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 255.3ms
# Speed: 1.3ms preprocess, 255.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 230.7ms
# Speed: 1.9ms preprocess, 230.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 222.4ms
# Speed: 1.3ms preprocess, 222.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 224.0ms
# Speed: 1.2ms preprocess, 224.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 224.1ms
# Speed: 1.3ms preprocess, 224.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 229.0ms
# Speed: 1.4ms preprocess, 229.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 229.2ms
# Speed: 1.7ms preprocess, 229.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 223.4ms
# Speed: 1.5ms preprocess, 223.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 223.2ms
# Speed: 1.3ms preprocess, 223.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 226.9ms
# Speed: 1.2ms preprocess, 226.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 225.5ms
# Speed: 1.6ms preprocess, 225.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 226.4ms
# Speed: 1.3ms preprocess, 226.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 229.0ms
# Speed: 1.4ms preprocess, 229.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 224.9ms
# Speed: 1.1ms preprocess, 224.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 226.9ms
# Speed: 1.1ms preprocess, 226.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 231.0ms
# Speed: 1.2ms preprocess, 231.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 224.5ms
# Speed: 1.2ms preprocess, 224.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 230.6ms
# Speed: 1.7ms preprocess, 230.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 228.6ms
# Speed: 1.4ms preprocess, 228.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 232.9ms
# Speed: 1.5ms preprocess, 232.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 238.0ms
# Speed: 1.2ms preprocess, 238.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 227.1ms
# Speed: 1.2ms preprocess, 227.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 231.7ms
# Speed: 1.2ms preprocess, 231.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 222.6ms
# Speed: 1.3ms preprocess, 222.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 232.7ms
# Speed: 1.8ms preprocess, 232.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 227.0ms
# Speed: 1.1ms preprocess, 227.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 228.5ms
# Speed: 1.4ms preprocess, 228.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 227.5ms
# Speed: 1.3ms preprocess, 227.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 225.7ms
# Speed: 1.1ms preprocess, 225.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 230.5ms
# Speed: 1.6ms preprocess, 230.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 229.6ms
# Speed: 1.4ms preprocess, 229.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 226.7ms
# Speed: 1.2ms preprocess, 226.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 231.8ms
# Speed: 1.3ms preprocess, 231.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 228.8ms
# Speed: 1.4ms preprocess, 228.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 226.7ms
# Speed: 1.4ms preprocess, 226.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 228.3ms
# Speed: 1.3ms preprocess, 228.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 cup, 3 chairs, 226.8ms
# Speed: 1.5ms preprocess, 226.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 243.2ms
# Speed: 1.1ms preprocess, 243.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 227.1ms
# Speed: 1.2ms preprocess, 227.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 232.7ms
# Speed: 1.6ms preprocess, 232.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 232.9ms
# Speed: 1.1ms preprocess, 232.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 226.8ms
# Speed: 1.3ms preprocess, 226.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 231.6ms
# Speed: 1.6ms preprocess, 231.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 229.7ms
# Speed: 1.7ms preprocess, 229.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 243.4ms
# Speed: 1.8ms preprocess, 243.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 236.8ms
# Speed: 1.9ms preprocess, 236.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 234.1ms
# Speed: 1.2ms preprocess, 234.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 226.7ms
# Speed: 1.3ms preprocess, 226.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 226.3ms
# Speed: 1.4ms preprocess, 226.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 229.7ms
# Speed: 1.4ms preprocess, 229.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 226.3ms
# Speed: 1.4ms preprocess, 226.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 229.2ms
# Speed: 1.7ms preprocess, 229.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 227.2ms
# Speed: 1.4ms preprocess, 227.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 230.9ms
# Speed: 1.7ms preprocess, 230.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 1 laptop, 242.3ms
# Speed: 1.8ms preprocess, 242.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 1 laptop, 232.4ms
# Speed: 1.2ms preprocess, 232.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 227.6ms
# Speed: 2.0ms preprocess, 227.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 1 laptop, 230.4ms
# Speed: 1.5ms preprocess, 230.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 3 chairs, 229.1ms
# Speed: 1.4ms preprocess, 229.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 1 laptop, 226.9ms
# Speed: 1.3ms preprocess, 226.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 234.2ms
# Speed: 1.4ms preprocess, 234.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 229.1ms
# Speed: 1.6ms preprocess, 229.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 230.4ms
# Speed: 1.8ms preprocess, 230.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 229.3ms
# Speed: 1.3ms preprocess, 229.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 chairs, 231.0ms
# Speed: 1.4ms preprocess, 231.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 chairs, 231.8ms
# Speed: 1.4ms preprocess, 231.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 chairs, 228.2ms
# Speed: 1.4ms preprocess, 228.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 chairs, 305.9ms
# Speed: 1.4ms preprocess, 305.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 225.3ms
# Speed: 1.2ms preprocess, 225.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 227.7ms
# Speed: 1.2ms preprocess, 227.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 231.7ms
# Speed: 1.2ms preprocess, 231.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 chairs, 1 vase, 226.1ms
# Speed: 1.6ms preprocess, 226.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 230.3ms
# Speed: 1.4ms preprocess, 230.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 226.5ms
# Speed: 2.6ms preprocess, 226.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 233.5ms
# Speed: 1.4ms preprocess, 233.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 227.6ms
# Speed: 1.3ms preprocess, 227.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 237.5ms
# Speed: 1.9ms preprocess, 237.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 225.4ms
# Speed: 1.4ms preprocess, 225.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 235.3ms
# Speed: 1.4ms preprocess, 235.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 2 chairs, 233.8ms
# Speed: 1.2ms preprocess, 233.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 2 chairs, 231.7ms
# Speed: 1.2ms preprocess, 231.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
# Speed: 1.3ms preprocess, 251.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 248.0ms
# Speed: 1.7ms preprocess, 248.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 248.3ms
# Speed: 1.4ms preprocess, 248.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 255.7ms
# Speed: 1.3ms preprocess, 255.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Successfully sent count 4 to ESP8266
#
# 0: 384x640 4 persons, 1 dining table, 256.4ms
# Speed: 5.4ms preprocess, 256.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Successfully sent count 3 to ESP8266
#
# 0: 384x640 4 persons, 1 dining table, 269.9ms
# Speed: 1.3ms preprocess, 269.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 252.8ms
# Speed: 1.3ms preprocess, 252.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 245.2ms
# Speed: 1.5ms preprocess, 245.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 244.1ms
# Speed: 1.3ms preprocess, 244.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 252.1ms
# Speed: 1.5ms preprocess, 252.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 246.4ms
# Speed: 1.9ms preprocess, 246.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 242.7ms
# Speed: 1.6ms preprocess, 242.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 240.5ms
# Speed: 1.4ms preprocess, 240.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 247.5ms
# Speed: 1.3ms preprocess, 247.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 247.0ms
# Speed: 1.3ms preprocess, 247.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 246.5ms
# Speed: 1.4ms preprocess, 246.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 240.5ms
# Speed: 1.4ms preprocess, 240.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 269.2ms
# Speed: 1.3ms preprocess, 269.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 242.8ms
# Speed: 1.4ms preprocess, 242.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 241.4ms
# Speed: 1.2ms preprocess, 241.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 238.7ms
# Speed: 1.3ms preprocess, 238.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 251.6ms
# Speed: 2.0ms preprocess, 251.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 247.8ms
# Speed: 1.8ms preprocess, 247.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 dining table, 249.0ms
# Speed: 1.5ms preprocess, 249.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 dining table, 246.5ms
# Speed: 1.5ms preprocess, 246.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 1 dining table, 247.8ms
# Speed: 1.4ms preprocess, 247.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 1 dining table, 246.9ms
# Speed: 1.8ms preprocess, 246.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 1 dining table, 243.2ms
# Speed: 1.7ms preprocess, 243.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 1 dining table, 243.6ms
# Speed: 1.5ms preprocess, 243.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 1 dining table, 249.9ms
# Speed: 1.4ms preprocess, 249.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 245.2ms
# Speed: 1.4ms preprocess, 245.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 253.5ms
# Speed: 1.6ms preprocess, 253.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 250.9ms
# Speed: 1.2ms preprocess, 250.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 241.4ms
# Speed: 1.3ms preprocess, 241.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 244.3ms
# Speed: 1.6ms preprocess, 244.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 247.5ms
# Speed: 1.5ms preprocess, 247.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 247.9ms
# Speed: 2.1ms preprocess, 247.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 243.0ms
# Speed: 1.4ms preprocess, 243.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 247.5ms
# Speed: 2.1ms preprocess, 247.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 247.2ms
# Speed: 1.5ms preprocess, 247.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 245.7ms
# Speed: 1.6ms preprocess, 245.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 248.1ms
# Speed: 2.0ms preprocess, 248.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 255.5ms
# Speed: 1.7ms preprocess, 255.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 1 dining table, 252.4ms
# Speed: 1.3ms preprocess, 252.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 252.2ms
# Speed: 1.5ms preprocess, 252.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 252.7ms
# Speed: 1.3ms preprocess, 252.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 252.7ms
# Speed: 1.3ms preprocess, 252.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 256.7ms
# Speed: 1.3ms preprocess, 256.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 248.1ms
# Speed: 1.4ms preprocess, 248.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 1 cell phone, 248.1ms
# Speed: 2.1ms preprocess, 248.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 1 cell phone, 250.5ms
# Speed: 1.3ms preprocess, 250.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 1 cell phone, 246.8ms
# Speed: 1.3ms preprocess, 246.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 1 cell phone, 250.4ms
# Speed: 1.3ms preprocess, 250.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 1 cell phone, 248.5ms
# Speed: 1.5ms preprocess, 248.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 1 dining table, 1 cell phone, 248.2ms
# Speed: 1.7ms preprocess, 248.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 1 cell phone, 246.8ms
# Speed: 1.7ms preprocess, 246.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 1 dining table, 247.7ms
# Speed: 1.6ms preprocess, 247.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 1 dining table, 248.9ms
# Speed: 1.2ms preprocess, 248.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 246.7ms
# Speed: 1.7ms preprocess, 246.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 248.2ms
# Speed: 1.5ms preprocess, 248.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 246.2ms
# Speed: 1.5ms preprocess, 246.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 248.1ms
# Speed: 1.5ms preprocess, 248.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 265.3ms
# Speed: 1.4ms preprocess, 265.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 247.3ms
# Speed: 1.5ms preprocess, 247.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 248.1ms
# Speed: 2.0ms preprocess, 248.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 249.8ms
# Speed: 1.4ms preprocess, 249.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 249.0ms
# Speed: 1.3ms preprocess, 249.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 265.5ms
# Speed: 1.8ms preprocess, 265.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 245.8ms
# Speed: 1.7ms preprocess, 245.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 248.9ms
# Speed: 1.4ms preprocess, 248.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 255.8ms
# Speed: 1.7ms preprocess, 255.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 244.7ms
# Speed: 1.7ms preprocess, 244.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 251.1ms
# Speed: 1.4ms preprocess, 251.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 248.0ms
# Speed: 1.4ms preprocess, 248.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 247.5ms
# Speed: 1.3ms preprocess, 247.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 248.6ms
# Speed: 1.5ms preprocess, 248.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 251.8ms
# Speed: 1.5ms preprocess, 251.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 247.7ms
# Speed: 1.3ms preprocess, 247.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 dining table, 254.2ms
# Speed: 1.4ms preprocess, 254.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 250.0ms
# Speed: 1.4ms preprocess, 250.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 246.1ms
# Speed: 1.4ms preprocess, 246.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 chairs, 1 dining table, 248.1ms
# Speed: 1.3ms preprocess, 248.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 chairs, 1 dining table, 257.2ms
# Speed: 1.9ms preprocess, 257.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 chairs, 1 dining table, 264.5ms
# Speed: 1.2ms preprocess, 264.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 chairs, 1 dining table, 246.7ms
# Speed: 1.3ms preprocess, 246.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 chairs, 1 dining table, 245.9ms
# Speed: 1.5ms preprocess, 245.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bottle, 2 chairs, 1 dining table, 255.7ms
# Speed: 1.4ms preprocess, 255.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 chair, 1 dining table, 254.7ms
# Speed: 1.4ms preprocess, 254.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bottle, 1 chair, 1 dining table, 246.2ms
# Speed: 1.6ms preprocess, 246.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Successfully sent count 4 to ESP8266
#
# 0: 384x640 4 persons, 1 tie, 1 chair, 1 dining table, 1 cell phone, 265.5ms
# Speed: 3.7ms preprocess, 265.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 1 chair, 1 dining table, 1 remote, 245.3ms
# Speed: 1.2ms preprocess, 245.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 1 chair, 1 dining table, 1 remote, 248.0ms
# Speed: 1.9ms preprocess, 248.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 chair, 1 dining table, 248.8ms
# Speed: 1.3ms preprocess, 248.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 chair, 1 dining table, 242.4ms
# Speed: 2.0ms preprocess, 242.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 chair, 1 dining table, 251.1ms
# Speed: 1.3ms preprocess, 251.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Successfully sent count 3 to ESP8266
#
# 0: 384x640 5 persons, 1 chair, 1 dining table, 269.5ms
# Speed: 1.7ms preprocess, 269.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 1 cell phone, 255.4ms
# Speed: 1.4ms preprocess, 255.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 1 dining table, 1 cell phone, 258.2ms
# Speed: 1.3ms preprocess, 258.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 1 dining table, 1 cell phone, 245.2ms
# Speed: 1.4ms preprocess, 245.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 1 cell phone, 246.3ms
# Speed: 1.3ms preprocess, 246.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 1 cell phone, 247.8ms
# Speed: 2.2ms preprocess, 247.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 1 cell phone, 254.3ms
# Speed: 1.4ms preprocess, 254.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 1 dining table, 1 cell phone, 246.8ms
# Speed: 1.4ms preprocess, 246.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
